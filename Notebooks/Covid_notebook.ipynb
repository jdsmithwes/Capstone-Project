# %%
import pandas as pd

# %% [markdown]
# ## Objective
#
# For the purpose of this analysis, I will attempt to measure the sentiment of tweets to learn whether tweets impact the number of Covid-19 cases and deaths in the United States.
#
# To create the dataset, I utilized the TWINT library to collect all tweets from January 1,2020 until July 10th. I then made various subsets of the tweets. For example, to measure the impact of tweets by public leaders viewed as polar opposites regarding their response to the pandemic, I collected tweets by President Trump and the Governor of New York, Andrew Cuomo. Another subset of tweets that I labeled as baseline consists of tweets by the New York Times and Washington Post - two of America's leading journalism outlets.
#
# The purpose of creating these subsets is that the baseline tweets can be considered to be those that communicate mainly fact. While they might have op-ed columnists, we can assume that most tweets from the news reporting divisions will provide factual updates on the Covid response. By considering the two polar opposites, Trump and Cuomo, we can measure Covid outcomes, in terms of cases, after the tweets have been consumed by the public. Finally, the main Covid collection will allow us to see whether more individuals subscribed to the Trump/Cuomo tweets and how Covid cases changed, for the positive or negative, in their region.

# %% [markdown]
# ## Obtaining Data

# %% [markdown]
# For the notebooks that contain the queries for the tweets gathered on TWINT, please refer to the Covid Data Queries notebook in the repo. The JSON files for these queries were used to create DataFrames.

# %%
#All Covid tweets
All_Covid_tweets = pd.read_json('Covid_tweets3.json',lines=True)

#All Trump tweets
Trump_Covid_tweets = pd.read_json('Trump_Covid_tweets3.json', lines=True)

#All Cuomo tweets
Cuomo_Covid_tweets = pd.read_json('Cuomo_Covid_tweets3.json',lines=True)

#Baseline Tweets
NYTimes_tweets = pd.read_json('Nytimes_Covid_tweets3.json',lines=True)
#print( len(NYTimes_tweets))
WashingtonPost_tweets = pd.read_json('Washpost_tweets3.json',lines=True)
#print( len(Washpost_tweets3.json))

#combining NYTimes and Washington Post to get Baseline Tweets
Baseline_tweets = pd.concat([NYTimes_tweets,WashingtonPost_tweets],axis=0)

#Reformatting Date columns for later merge
All_Covid_tweets['Date'] = All_Covid_tweets['date']
Trump_Covid_tweets['Date'] = Trump_Covid_tweets['date']
Cuomo_Covid_tweets['Date'] = Cuomo_Covid_tweets['date']
Baseline_tweets['Date'] = Baseline_tweets['date']

# %% [markdown]
# Data for Covid Cases and Deaths was collected from The COVID Tracking Project.

# %%
# Covid data set

covid_cases = pd.read_csv('time_series_covid_19_confirmed.csv')

#Getting US data - confirmed cases
covid_cases = covid_cases[covid_cases['Country/Region'] == 'US']
#covid_cases = covid_cases.transpose()

# Covid death data set

covid_deaths = pd.read_csv('time_series_covid_19_deaths.csv')


#Getting US data - confirmed cases

#covid_deaths = covid_deaths.transpose()
covid_deaths = covid_deaths[covid_deaths['Country/Region'] == 'US']

# %%
#Covid cases and deaths (still need to rename columns, from left to right = cases then deaths)
covid_data = pd.concat([covid_cases,covid_deaths],axis=0)
covid_data = covid_data.transpose()

# %%
covid_data = covid_data.drop(['Province/State','Country/Region','Lat','Long'])

# %%
covid_data.head()
# Out:
#         225 225
# 1/22/20   1   0
# 1/23/20   1   0
# 1/24/20   2   0
# 1/25/20   2   0
# 1/26/20   5   0

# %% [markdown]
# ### Adding Case/Death Data on Day of the Tweet

# %%
#Edited column names in Excel for Merge
covid_data_formatted = pd.read_excel('covid_data_date.xlsx')
covid_data_formatted.head()
# Out:
#       Date  Cases  Deaths
# 0  1/22/20      1       0
# 1  1/23/20      1       0
# 2  1/24/20      2       0
# 3  1/25/20      2       0
# 4  1/26/20      5       0

# %%
#Converting all Date columns to datetime for Merge
covid_data_formatted['Date'] = pd.to_datetime(covid_data_formatted['Date'])
All_Covid_tweets['Date'] = pd.to_datetime(All_Covid_tweets['Date'])
Trump_Covid_tweets['Date'] = pd.to_datetime(Trump_Covid_tweets['Date'])
Cuomo_Covid_tweets['Date'] = pd.to_datetime(Cuomo_Covid_tweets['Date'])
Baseline_tweets['Date'] = pd.to_datetime(Baseline_tweets['Date'])

# %%
#All Tweet Data with corresponding case/death information
All_Covid_tweets_case_data = pd.merge(All_Covid_tweets,covid_data_formatted,on='Date')
#Trump Tweet Data with corresponding case/death information
Trump_Covid_tweets_case_data = pd.merge(Trump_Covid_tweets,covid_data_formatted,on='Date')
#Cuomo Tweet Data with corresponding case/death information
Cuomo_Covid_tweets_case_data = pd.merge(Cuomo_Covid_tweets,covid_data_formatted, on='Date')
#Baseline Tweet Data with corresponding case/death information
Baseline_tweets_case_data = pd.merge(Baseline_tweets,covid_data_formatted,on='Date')

# %% [markdown]
# ### Adding case/death data for two weeks after original tweet

# %%
#Getting date two weeks from now for Covid case/death reaction to Tweets
from datetime import datetime,timedelta

N = 14
days_N_from_now = All_Covid_tweets['Date'] + timedelta(days=N)

All_Covid_tweets_case_data['14 days'] = (All_Covid_tweets_case_data['Date'] + timedelta(days=N))
Trump_Covid_tweets_case_data['14 days'] = (Trump_Covid_tweets_case_data['Date'] + timedelta(days=N))
Cuomo_Covid_tweets_case_data['14 days'] = (Cuomo_Covid_tweets_case_data['Date'] +timedelta(days=N))
Baseline_tweets_case_data['14 days'] = (Baseline_tweets_case_data['Date'] + timedelta(days=N))

# %%
covid_data_two_week = pd.read_excel('covid_data_14days.xlsx')
covid_data_two_week.head()
# Out:
#    14 days  Cases  Deaths
# 0  1/22/20      1       0
# 1  1/23/20      1       0
# 2  1/24/20      2       0
# 3  1/25/20      2       0
# 4  1/26/20      5       0

# %%
#Converting all Date columns to datetime for Merge
covid_data_two_week['14 days'] = pd.to_datetime(covid_data_two_week['14 days'])
All_Covid_tweets_case_data['14 days'] = pd.to_datetime(All_Covid_tweets_case_data['14 days'])
Trump_Covid_tweets_case_data['14 days'] = pd.to_datetime(Trump_Covid_tweets_case_data['14 days'])
Cuomo_Covid_tweets_case_data['14 days'] = pd.to_datetime(Cuomo_Covid_tweets_case_data['14 days'])
Baseline_tweets_case_data['14 days'] = pd.to_datetime(Baseline_tweets_case_data['14 days'])

# %%
#All Tweet Data with corresponding case/death information
All_Covid_tweets_case_data = pd.merge(All_Covid_tweets_case_data,covid_data_two_week,on='14 days')
#Trump Tweet Data with corresponding case/death information
Trump_Covid_tweets_case_data = pd.merge(Trump_Covid_tweets_case_data,covid_data_two_week,on='14 days')
#Cuomo Tweet Data with corresponding case/death information
Cuomo_Covid_tweets_case_data = pd.merge(Cuomo_Covid_tweets_case_data,covid_data_two_week, on='14 days')
#Baseline Tweet Data with corresponding case/death information
Baseline_tweets_case_data = pd.merge(Baseline_tweets_case_data,covid_data_two_week,on='14 days')

# %% [markdown]
# ### Adding Case/Death Data for four weeks after original tweet

# %%
covid_data_four_week = pd.read_excel('covid_data_28days.xlsx')
covid_data_four_week.head()
# Out:
#    28 days  Cases  Deaths
# 0  1/22/20      1       0
# 1  1/23/20      1       0
# 2  1/24/20      2       0
# 3  1/25/20      2       0
# 4  1/26/20      5       0

# %%
#Getting date two weeks from now for Covid case/death reaction to Tweets
from datetime import datetime,timedelta

N = 28
days_N_from_now = All_Covid_tweets['Date'] + timedelta(days=N)

All_Covid_tweets_case_data['28 days'] = (All_Covid_tweets_case_data['Date'] + timedelta(days=N))
Trump_Covid_tweets_case_data['28 days'] = (Trump_Covid_tweets_case_data['Date'] + timedelta(days=N))
Cuomo_Covid_tweets_case_data['28 days'] = (Cuomo_Covid_tweets_case_data['Date'] +timedelta(days=N))
Baseline_tweets_case_data['28 days'] = (Baseline_tweets_case_data['Date'] + timedelta(days=N))

# %%
#Converting all Date columns to datetime for Merge
covid_data_four_week['28 days'] = pd.to_datetime(covid_data_four_week['28 days'])
All_Covid_tweets_case_data['28 days'] = pd.to_datetime(All_Covid_tweets_case_data['28 days'])
Trump_Covid_tweets_case_data['28 days'] = pd.to_datetime(Trump_Covid_tweets_case_data['28 days'])
Cuomo_Covid_tweets_case_data['28 days'] = pd.to_datetime(Cuomo_Covid_tweets_case_data['28 days'])
Baseline_tweets_case_data['28 days'] = pd.to_datetime(Baseline_tweets_case_data['28 days'])

# %%
#All Tweet Data with corresponding case/death information
All_Covid_tweets_case_data = pd.merge(All_Covid_tweets_case_data,covid_data_four_week,on='28 days')
#Trump Tweet Data with corresponding case/death information
Trump_Covid_tweets_case_data = pd.merge(Trump_Covid_tweets_case_data,covid_data_four_week,on='28 days')
#Cuomo Tweet Data with corresponding case/death information
Cuomo_Covid_tweets_case_data = pd.merge(Cuomo_Covid_tweets_case_data,covid_data_four_week, on='28 days')
#Baseline Tweet Data with corresponding case/death information
Baseline_tweets_case_data = pd.merge(Baseline_tweets_case_data,covid_data_four_week,on='28 days')

# %%
Baseline_tweets_case_data.head()
# Out:
#   cashtags      conversation_id          created_at       date geo hashtags  \
# 0       []  1270707306578264064 2020-06-10 13:20:05 2020-06-10           []
# 1       []  1270636833555308544 2020-06-10 08:40:03 2020-06-10           []
# 2       []  1270815442173603840 2020-06-10 20:29:46 2020-06-10           []
# 3       []  1270541216308957184 2020-06-10 02:20:06 2020-06-09           []
# 4       []  1270470755889840128 2020-06-09 21:40:07 2020-06-09           []
#
#                     id  likes_count  \
# 0  1270707306578264065          209
# 1  1270636833555308544          857
# 2  1270815442173603841          159
# 3  1270541216308957184          382
# 4  1270470755889840134          404
#
#                                                 link  mentions  ... video  \
# 0  https://twitter.com/nytimes/status/12707073065...        []  ...     0
# 1  https://twitter.com/nytimes/status/12706368335...        []  ...     0
# 2  https://twitter.com/washingtonpost/status/1270...        []  ...     0
# 3  https://twitter.com/nytimes/status/12705412163...  [nytmag]  ...     0
# 4  https://twitter.com/nytimes/status/12704707558...  [nytmag]  ...     0
#
#         Date  Cases_x Deaths_x    14 days  Cases_y Deaths_y    28 days  \
# 0 2020-06-10  2000702   113631 2020-06-24  2382426   122604 2020-07-08
# 1 2020-06-10  2000702   113631 2020-06-24  2382426   122604 2020-07-08
# 2 2020-06-10  2000702   113631 2020-06-24  2382426   122604 2020-07-08
# 3 2020-06-09  1979908   112714 2020-06-23  2347491   121847 2020-07-07
# 4 2020-06-09  1979908   112714 2020-06-23  2347491   121847 2020-07-07
#
#      Cases  Deaths
# 0  3054699  132300
# 1  3054699  132300
# 2  3054699  132300
# 3  2996098  131480
# 4  2996098  131480
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Combined Tweet DataFrame

# %%
#Tweet dataframes combined

Master_Tweet_df = pd.concat([All_Covid_tweets_case_data,Trump_Covid_tweets_case_data,Cuomo_Covid_tweets_case_data,Baseline_tweets_case_data])

# %%
pip install optimuspyspark
# Out:
# Collecting optimuspyspark
#   Using cached https://files.pythonhosted.org/packages/53/bd/da629b92ece647f8a37525b298e085d5c2367ada2db2a5cfcf63e8af1beb/optimuspyspark-2.2.29-py3-none-any.whl
# Requirement already satisfied: ipython==7.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (7.5.0)
# Requirement already satisfied: imgkit==1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.1)
# Requirement already satisfied: requests==2.20.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.20.0)
# Requirement already satisfied: humanize==0.5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.5.1)
# Requirement already satisfied: Jinja2==2.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.10.1)
# Requirement already satisfied: numpy==1.17.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.17.2)
# Requirement already satisfied: pyarrow==0.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.13.0)
# Collecting pypika==0.32.0 (from optimuspyspark)
# Requirement already satisfied: tqdm==4.28.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.28.1)
# Requirement already satisfied: singleton-decorator==1.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.0)
# Requirement already satisfied: keras==2.2.4 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.4)
# Requirement already satisfied: deepdiff==4.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.0.6)
# Collecting psutil==5.6.3 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/1c/ca/5b8c1fe032a458c2c4bcbe509d1401dca9dda35c7fc46b36bb81c2834740/psutil-5.6.3.tar.gz
# Requirement already satisfied: pyspark==2.4.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.1)
# Collecting packaging==19.1 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/ec/22/630ac83e8f8a9566c4f88038447ed9e16e6f10582767a01f31c769d9a71e/packaging-19.1-py2.py3-none-any.whl
# Requirement already satisfied: h2o-pysparkling-2.4==2.4.13 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.13)
# Requirement already satisfied: cryptography==2.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.7)
# Requirement already satisfied: fastnumbers==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Requirement already satisfied: ratelimit==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Requirement already satisfied: flask==1.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.2)
# Requirement already satisfied: pandas==0.24.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.24.2)
# Requirement already satisfied: glom==19.10.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (19.10.0)
# Requirement already satisfied: statsmodels==0.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.10.1)
# Requirement already satisfied: deprecated==1.2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.2.5)
# Requirement already satisfied: ordered-set==3.1.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.1.1)
# Requirement already satisfied: pygments>=2.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.2)
# Requirement already satisfied: tensorflow==1.13.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.13.1)
# Requirement already satisfied: pymongo==3.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.9.0)
# Requirement already satisfied: multipledispatch==0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.6.0)
# Collecting simplejson==3.16.0 (from optimuspyspark)
# Requirement already satisfied: matplotlib==3.0.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.0.3)
# Requirement already satisfied: seaborn==0.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.9.0)
# Requirement already satisfied: findspark==1.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.3.0)
# Requirement already satisfied: kombu==4.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.6.1)
# Requirement already satisfied: setuptools==41.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (41.6.0)
# Collecting backoff==1.8.0 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/00/b9/b045f0fe02aa80cefc5a6921d5f7674db58c1658d0e4b888562c15ef6aba/backoff-1.8.0-py2.py3-none-any.whl
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (2.0.9)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.3.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.7.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.4.0)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.15.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (1.24.2)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from Jinja2==2.10.1->optimuspyspark) (1.1.1)
# Requirement already satisfied: six>=1.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pyarrow==0.13.0->optimuspyspark) (1.12.0)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.1.2)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (5.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.4.1)
# Requirement already satisfied: jsonpickle>=1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deepdiff==4.0.6->optimuspyspark) (1.4.1)
# Requirement already satisfied: py4j==0.10.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pyspark==2.4.1->optimuspyspark) (0.10.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (2.4.2)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (19.1.0)
# Requirement already satisfied: colorama>=0.3.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.4.3)
# Requirement already satisfied: future in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.18.2)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.8.7)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (1.12.3)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.0.1)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2019.2)
# Requirement already satisfied: face in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.1.1)
# Requirement already satisfied: boltons>=19.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.2.0)
# Requirement already satisfied: patsy>=0.4.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from statsmodels==0.10.1->optimuspyspark) (0.5.1)
# Requirement already satisfied: wrapt<2,>=1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deprecated==1.2.5->optimuspyspark) (1.11.2)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.8.1)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.33.6)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (3.12.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.29.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.3.3)
# Requirement already satisfied: absl-py>=0.1.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (0.10.0)
# Requirement already satisfied: amqp<3.0,>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from kombu==4.6.1->optimuspyspark) (2.6.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython==7.5.0->optimuspyspark) (0.1.7)
# Requirement already satisfied: ipython_genutils in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from traitlets>=4.2->ipython==7.5.0->optimuspyspark) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython==7.5.0->optimuspyspark) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jedi>=0.10->ipython==7.5.0->optimuspyspark) (0.5.1)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (1.5.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography==2.7->optimuspyspark) (2.19)
# Requirement already satisfied: mock>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (4.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (3.2.2)
# Requirement already satisfied: vine<5.0.0a1,>=1.1.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from amqp<3.0,>=2.5.0->kombu==4.6.1->optimuspyspark) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from importlib-metadata->jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (3.1.0)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-wheel-4po3ho3u --python-tag cp36
#        cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/
#   Complete output (50 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   running build_ext
#   building 'psutil._psutil_osx' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#   In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                    from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                    from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                    from psutil/_psutil_common.c:9:
#   /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#    #include_next <limits.h>  /* recurse down to the real one */
#                                                                ^
#   compilation terminated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psutil
#   Running setup.py clean for psutil
# Failed to build psutil
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# Installing collected packages: pypika, psutil, packaging, simplejson, backoff, optimuspyspark
#   Found existing installation: psutil 5.7.0
#     Uninstalling psutil-5.7.0:
#       Successfully uninstalled psutil-5.7.0
#   Running setup.py install for psutil ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-wpkui6tp/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/
#     Complete output (50 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     running build_ext
#     building 'psutil._psutil_osx' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#     In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                      from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                      from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                      from psutil/_psutil_common.c:9:
#     /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#      #include_next <limits.h>  /* recurse down to the real one */
#                                                                  ^
#     compilation terminated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of psutil
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil-5.7.0.dist-info/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil-5.7.0.dist-info
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil
# ERROR: Command errored out with exit status 1: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-yklsus_p/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-wpkui6tp/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
from optimus import Optimus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-22e51d4255ae> in <module>
# ----> 1 from optimus import Optimus
#
# ModuleNotFoundError: No module named 'optimus'

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (2.4.1)
# Requirement already satisfied: py4j==0.10.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pyspark) (0.10.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optimuspyspark
# Out:
# Collecting optimuspyspark
#   Using cached https://files.pythonhosted.org/packages/53/bd/da629b92ece647f8a37525b298e085d5c2367ada2db2a5cfcf63e8af1beb/optimuspyspark-2.2.29-py3-none-any.whl
# Requirement already satisfied: ipython==7.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (7.5.0)
# Requirement already satisfied: statsmodels==0.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.10.1)
# Requirement already satisfied: fastnumbers==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Requirement already satisfied: pyspark==2.4.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.1)
# Requirement already satisfied: Jinja2==2.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.10.1)
# Requirement already satisfied: flask==1.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.2)
# Requirement already satisfied: numpy==1.17.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.17.2)
# Requirement already satisfied: multipledispatch==0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.6.0)
# Requirement already satisfied: setuptools==41.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (41.6.0)
# Requirement already satisfied: pyarrow==0.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.13.0)
# Requirement already satisfied: kombu==4.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.6.1)
# Requirement already satisfied: deprecated==1.2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.2.5)
# Requirement already satisfied: tqdm==4.28.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.28.1)
# Collecting psutil==5.6.3 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/1c/ca/5b8c1fe032a458c2c4bcbe509d1401dca9dda35c7fc46b36bb81c2834740/psutil-5.6.3.tar.gz
# Requirement already satisfied: pymongo==3.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.9.0)
# Requirement already satisfied: deepdiff==4.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.0.6)
# Requirement already satisfied: singleton-decorator==1.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.0)
# Collecting packaging==19.1 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/ec/22/630ac83e8f8a9566c4f88038447ed9e16e6f10582767a01f31c769d9a71e/packaging-19.1-py2.py3-none-any.whl
# Requirement already satisfied: ordered-set==3.1.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.1.1)
# Requirement already satisfied: requests==2.20.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.20.0)
# Requirement already satisfied: glom==19.10.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (19.10.0)
# Requirement already satisfied: pygments>=2.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.2)
# Requirement already satisfied: imgkit==1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.1)
# Requirement already satisfied: seaborn==0.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.9.0)
# Requirement already satisfied: pandas==0.24.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.24.2)
# Requirement already satisfied: h2o-pysparkling-2.4==2.4.13 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.13)
# Requirement already satisfied: tensorflow==1.13.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.13.1)
# Collecting backoff==1.8.0 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/00/b9/b045f0fe02aa80cefc5a6921d5f7674db58c1658d0e4b888562c15ef6aba/backoff-1.8.0-py2.py3-none-any.whl
# Requirement already satisfied: findspark==1.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.3.0)
# Requirement already satisfied: cryptography==2.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.7)
# Requirement already satisfied: humanize==0.5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.5.1)
# Requirement already satisfied: pypika==0.32.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.32.0)
# Requirement already satisfied: ratelimit==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Collecting simplejson==3.16.0 (from optimuspyspark)
# Requirement already satisfied: keras==2.2.4 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.4)
# Requirement already satisfied: matplotlib==3.0.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.15.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.3.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (2.0.9)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.7.0)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.4.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.7.5)
# Requirement already satisfied: scipy>=0.18 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from statsmodels==0.10.1->optimuspyspark) (1.4.1)
# Requirement already satisfied: patsy>=0.4.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from statsmodels==0.10.1->optimuspyspark) (0.5.1)
# Requirement already satisfied: py4j==0.10.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pyspark==2.4.1->optimuspyspark) (0.10.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from Jinja2==2.10.1->optimuspyspark) (1.1.1)
# Requirement already satisfied: Werkzeug>=0.14 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.0.1)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.1.0)
# Requirement already satisfied: six in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from multipledispatch==0.6.0->optimuspyspark) (1.12.0)
# Requirement already satisfied: amqp<3.0,>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from kombu==4.6.1->optimuspyspark) (2.6.0)
# Requirement already satisfied: wrapt<2,>=1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deprecated==1.2.5->optimuspyspark) (1.11.2)
# Requirement already satisfied: jsonpickle>=1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deepdiff==4.0.6->optimuspyspark) (1.4.1)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (19.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (2.4.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2020.6.20)
# Requirement already satisfied: face in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.1.1)
# Requirement already satisfied: boltons>=19.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.2.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2019.2)
# Requirement already satisfied: colorama>=0.3.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.4.3)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.8.7)
# Requirement already satisfied: future in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.18.2)
# Requirement already satisfied: absl-py>=0.1.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.9.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.0.8)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.1.0)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.29.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.3.3)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.33.6)
# Requirement already satisfied: astor>=0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.8.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (3.12.2)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (1.12.3)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (0.24.0)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (2.10.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (5.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (0.10.0)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jedi>=0.10->ipython==7.5.0->optimuspyspark) (0.5.1)
# Requirement already satisfied: ipython_genutils in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from traitlets>=4.2->ipython==7.5.0->optimuspyspark) (0.2.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython==7.5.0->optimuspyspark) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython==7.5.0->optimuspyspark) (0.6.0)
# Requirement already satisfied: vine<5.0.0a1,>=1.1.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from amqp<3.0,>=2.5.0->kombu==4.6.1->optimuspyspark) (1.3.0)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (1.5.0)
# Requirement already satisfied: mock>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (4.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (3.2.2)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography==2.7->optimuspyspark) (2.19)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from importlib-metadata->jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (3.1.0)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-wheel-07qkh38i --python-tag cp36
#        cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/
#   Complete output (50 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   running build_ext
#   building 'psutil._psutil_osx' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#   In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                    from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                    from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                    from psutil/_psutil_common.c:9:
#   /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#    #include_next <limits.h>  /* recurse down to the real one */
#                                                                ^
#   compilation terminated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psutil
#   Running setup.py clean for psutil
# Failed to build psutil
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# Installing collected packages: psutil, packaging, backoff, simplejson, optimuspyspark
#   Found existing installation: psutil 5.7.0
#     Uninstalling psutil-5.7.0:
#       Successfully uninstalled psutil-5.7.0
#   Running setup.py install for psutil ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-okwq5bnc/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/
#     Complete output (50 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     running build_ext
#     building 'psutil._psutil_osx' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#     In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                      from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                      from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                      from psutil/_psutil_common.c:9:
#     /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#      #include_next <limits.h>  /* recurse down to the real one */
#                                                                  ^
#     compilation terminated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of psutil
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil-5.7.0.dist-info/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil-5.7.0.dist-info
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil
# ERROR: Command errored out with exit status 1: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-vlkjn98z/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-okwq5bnc/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
import optimus as op
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-0f272e8fc6d6> in <module>
# ----> 1 import optimus as op
#
# ModuleNotFoundError: No module named 'optimus'

# %%
pip install optimuspyspark
# Out:
# Collecting optimuspyspark
#   Using cached https://files.pythonhosted.org/packages/53/bd/da629b92ece647f8a37525b298e085d5c2367ada2db2a5cfcf63e8af1beb/optimuspyspark-2.2.29-py3-none-any.whl
# Collecting psutil==5.6.3 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/1c/ca/5b8c1fe032a458c2c4bcbe509d1401dca9dda35c7fc46b36bb81c2834740/psutil-5.6.3.tar.gz
# Requirement already satisfied: deepdiff==4.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.0.6)
# Requirement already satisfied: pyspark==2.4.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.1)
# Requirement already satisfied: keras==2.2.4 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.4)
# Requirement already satisfied: requests==2.20.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.20.0)
# Collecting backoff==1.8.0 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/00/b9/b045f0fe02aa80cefc5a6921d5f7674db58c1658d0e4b888562c15ef6aba/backoff-1.8.0-py2.py3-none-any.whl
# Requirement already satisfied: singleton-decorator==1.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.0)
# Requirement already satisfied: seaborn==0.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.9.0)
# Collecting packaging==19.1 (from optimuspyspark)
#   Using cached https://files.pythonhosted.org/packages/ec/22/630ac83e8f8a9566c4f88038447ed9e16e6f10582767a01f31c769d9a71e/packaging-19.1-py2.py3-none-any.whl
# Requirement already satisfied: glom==19.10.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (19.10.0)
# Requirement already satisfied: pymongo==3.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.9.0)
# Requirement already satisfied: tqdm==4.28.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.28.1)
# Requirement already satisfied: imgkit==1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.1)
# Requirement already satisfied: humanize==0.5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.5.1)
# Requirement already satisfied: deprecated==1.2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.2.5)
# Requirement already satisfied: pyarrow==0.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.13.0)
# Requirement already satisfied: findspark==1.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.3.0)
# Requirement already satisfied: flask==1.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.0.2)
# Requirement already satisfied: fastnumbers==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Requirement already satisfied: pandas==0.24.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.24.2)
# Requirement already satisfied: statsmodels==0.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.10.1)
# Requirement already satisfied: numpy==1.17.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.17.2)
# Requirement already satisfied: multipledispatch==0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.6.0)
# Requirement already satisfied: pygments>=2.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.2)
# Requirement already satisfied: matplotlib==3.0.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.0.3)
# Collecting simplejson==3.16.0 (from optimuspyspark)
# Requirement already satisfied: ordered-set==3.1.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (3.1.1)
# Requirement already satisfied: ipython==7.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (7.5.0)
# Requirement already satisfied: pypika==0.32.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (0.32.0)
# Requirement already satisfied: kombu==4.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (4.6.1)
# Requirement already satisfied: Jinja2==2.10.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.10.1)
# Requirement already satisfied: ratelimit==2.2.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.2.1)
# Requirement already satisfied: cryptography==2.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.7)
# Requirement already satisfied: tensorflow==1.13.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (1.13.1)
# Requirement already satisfied: setuptools==41.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (41.6.0)
# Requirement already satisfied: h2o-pysparkling-2.4==2.4.13 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from optimuspyspark) (2.4.13)
# Requirement already satisfied: jsonpickle>=1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deepdiff==4.0.6->optimuspyspark) (1.4.1)
# Requirement already satisfied: py4j==0.10.7 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pyspark==2.4.1->optimuspyspark) (0.10.7)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.12.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (5.3.1)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from keras==2.2.4->optimuspyspark) (1.0.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (1.24.2)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests==2.20.0->optimuspyspark) (2020.6.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (2.4.2)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from packaging==19.1->optimuspyspark) (19.1.0)
# Requirement already satisfied: face in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.1.1)
# Requirement already satisfied: boltons>=19.3.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from glom==19.10.0->optimuspyspark) (20.2.0)
# Requirement already satisfied: wrapt<2,>=1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from deprecated==1.2.5->optimuspyspark) (1.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.14 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (1.0.1)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from flask==1.0.2->optimuspyspark) (7.1.2)
# Requirement already satisfied: pytz>=2011k in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2019.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas==0.24.2->optimuspyspark) (2.8.0)
# Requirement already satisfied: patsy>=0.4.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from statsmodels==0.10.1->optimuspyspark) (0.5.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from matplotlib==3.0.3->optimuspyspark) (1.1.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.3.2)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.7.5)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.7.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (2.0.9)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (4.4.0)
# Requirement already satisfied: jedi>=0.10 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from ipython==7.5.0->optimuspyspark) (0.15.1)
# Requirement already satisfied: amqp<3.0,>=2.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from kombu==4.6.1->optimuspyspark) (2.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from Jinja2==2.10.1->optimuspyspark) (1.1.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (1.12.3)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cryptography==2.7->optimuspyspark) (0.24.0)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.8.1)
# Requirement already satisfied: absl-py>=0.1.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.9.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.3.3)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.13.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.29.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (3.12.2)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow==1.13.1->optimuspyspark) (0.33.6)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.8.7)
# Requirement already satisfied: future in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.18.2)
# Requirement already satisfied: colorama>=0.3.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from h2o-pysparkling-2.4==2.4.13->optimuspyspark) (0.4.3)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (1.5.0)
# Requirement already satisfied: ipython_genutils in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from traitlets>=4.2->ipython==7.5.0->optimuspyspark) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython==7.5.0->optimuspyspark) (0.6.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython==7.5.0->optimuspyspark) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from jedi>=0.10->ipython==7.5.0->optimuspyspark) (0.5.1)
# Requirement already satisfied: vine<5.0.0a1,>=1.1.3 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from amqp<3.0,>=2.5.0->kombu==4.6.1->optimuspyspark) (1.3.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography==2.7->optimuspyspark) (2.19)
# Requirement already satisfied: mock>=2.0.0 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (4.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.1->optimuspyspark) (3.2.2)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from importlib-metadata->jsonpickle>=1.0->deepdiff==4.0.6->optimuspyspark) (3.1.0)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-wheel-02igxjeh --python-tag cp36
#        cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/
#   Complete output (50 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#   creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#   running build_ext
#   building 'psutil._psutil_osx' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#   creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#   In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                    from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                    from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                    from psutil/_psutil_common.c:9:
#   /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#    #include_next <limits.h>  /* recurse down to the real one */
#                                                                ^
#   compilation terminated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psutil
#   Running setup.py clean for psutil
# Failed to build psutil
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# Installing collected packages: psutil, backoff, packaging, simplejson, optimuspyspark
#   Found existing installation: psutil 5.7.0
#     Uninstalling psutil-5.7.0:
#       Successfully uninstalled psutil-5.7.0
#   Running setup.py install for psutil ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-h_tk5ezj/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/
#     Complete output (50 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pswindows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_common.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psosx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psbsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psaix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pslinux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_compat.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_psposix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     copying psutil/_pssunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil
#     creating build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_contracts.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_connections.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/runner.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_unicode.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_misc.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_posix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_linux.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_sunos.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_aix.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_process.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_bsd.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_system.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_osx.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_memory_leaks.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/test_windows.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     copying psutil/tests/__main__.py -> build/lib.macosx-10.7-x86_64-3.6/psutil/tests
#     running build_ext
#     building 'psutil._psutil_osx' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch
#     creating build/temp.macosx-10.7-x86_64-3.6/psutil/arch/osx
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -I/opt/anaconda3/envs/learn-env/include -arch x86_64 -DPSUTIL_POSIX=1 -DPSUTIL_VERSION=563 -DPSUTIL_OSX=1 -I/opt/anaconda3/envs/learn-env/include/python3.6m -c psutil/_psutil_common.c -o build/temp.macosx-10.7-x86_64-3.6/psutil/_psutil_common.o
#     In file included from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/syslimits.h:7:0,
#                      from /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:34,
#                      from /opt/anaconda3/envs/learn-env/include/python3.6m/Python.h:11,
#                      from psutil/_psutil_common.c:9:
#     /opt/anaconda3/envs/learn-env/lib/gcc/x86_64-apple-darwin11.4.2/4.8.5/include-fixed/limits.h:168:61: fatal error: limits.h: No such file or directory
#      #include_next <limits.h>  /* recurse down to the real one */
#                                                                  ^
#     compilation terminated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of psutil
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil-5.7.0.dist-info/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil-5.7.0.dist-info
#   Moving to /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/psutil/
#    from /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/~sutil
# ERROR: Command errored out with exit status 1: /opt/anaconda3/envs/learn-env/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"'; __file__='"'"'/private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-install-c103ubd_/psutil/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/24/g8m2m29n02ncczz28hys1_xw0000gn/T/pip-record-h_tk5ezj/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
from optimus import Optimus
op = Optimus()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-42e7e998596d> in <module>
# ----> 1 from optimus import Optimus
#       2 op = Optimus()
#
# ModuleNotFoundError: No module named 'optimus'
