# %%
import pandas as pd

# %%
poll = pd.read_csv('poll_df.csv')

# %%
poll.head()
# Out:
#    Unnamed: 0        Date         username  Sentiment                   Poll  \
# 0           0  2020-02-11          nytimes      0.136   QuinnipiacQuinnipiac
# 1           1  2020-02-13        tamiann02      0.256   QuinnipiacQuinnipiac
# 2           2  2020-02-13       1val1richy      0.256   QuinnipiacQuinnipiac
# 3           3  2020-02-13           kolsaw      0.061   QuinnipiacQuinnipiac
# 4           4  2020-02-15  _watch_observe_      0.217  NPR/PBS/MaristNPR/PBS
#
#    Start Date End Date   Sample  MoE  Biden (D)  Trump (R)    Spread
# 0  2020-02-05   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 1  2020-02-05   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 2  2020-02-05   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 3  2020-02-05   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 4  2020-02-13  2/16/20  1164 RV  3.7       50.0       44.0  Biden +6

# %%
poll = poll.drop(['Unnamed: 0'],axis=1)

# %%
poll.head()
# Out:
#          Date         username  Sentiment                   Poll  Start Date  \
# 0  2020-02-11          nytimes      0.136   QuinnipiacQuinnipiac  2020-02-05
# 1  2020-02-13        tamiann02      0.256   QuinnipiacQuinnipiac  2020-02-05
# 2  2020-02-13       1val1richy      0.256   QuinnipiacQuinnipiac  2020-02-05
# 3  2020-02-13           kolsaw      0.061   QuinnipiacQuinnipiac  2020-02-05
# 4  2020-02-15  _watch_observe_      0.217  NPR/PBS/MaristNPR/PBS  2020-02-13
#
#   End Date   Sample  MoE  Biden (D)  Trump (R)    Spread
# 0   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 1   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 2   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 3   2/9/20  1519 RV  2.5       50.0       43.0  Biden +7
# 4  2/16/20  1164 RV  3.7       50.0       44.0  Biden +6

# %%
Tweets = pd.read_csv('RawTweet_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5afd875661fe> in <module>
# ----> 1 Tweets = pd.read_csv('RawTweet_data.csv')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
